# %%
import pandas as pd

df_or = pd.read_csv("Y_0.csv")

df_or['is_malware'] = df_or['is_malware'].astype(bool)
df_or['is_dga'] = df_or['is_dga'].astype(bool)

df_or['legit'] = (df_or['is_malware'] == 0) & (df_or['is_dga'] == 0)

df_or['not_dga'] = (df_or['is_malware'] == True) & (df_or['is_dga'] == False)

df_or
# Out:
#             id  is_malware  is_dga        Y_none     Y_tld       Y_icann  \
# 885        885        True    True  1.337106e-05  0.125115  1.955169e-06
# 886        886        True    True  9.999689e-01  0.125115  1.955169e-06
# 1156      1156        True    True  3.919276e-09  0.000006  3.510921e-07
# 1468      1468        True    True  8.088952e-06  0.000081  3.281455e-09
# 1482      1482        True    True  1.092792e-08  0.006782  1.411106e-01
# ...        ...         ...     ...           ...       ...           ...
# 438238  438238        True    True  9.999977e-01  0.999999  5.254872e-01
# 438247  438247        True    True  9.999999e-01  0.999969  9.999812e-01
# 438251  438251        True    True  9.999996e-01  1.000000  1.000000e+00
# 438254  438254        True    True  9.999999e-01  0.999997  1.000000e+00
# 438259  438259        True    True  9.999999e-01  1.000000  1.000000e+00
#
#            Y_private  Y_none_first_17char  Y_tld_first_17char  \
# 885     3.136467e-01             0.000009            0.125115
# 886     3.136467e-01             0.320876            0.125115
# 1156    1.278853e-05             0.646038            0.000006
# 1468    8.181743e-07             0.814435            0.000081
# 1482    7.547356e-06             0.000190            0.006782
# ...              ...                  ...                 ...
# 438238  9.946175e-01             0.999998            0.999999
# 438247  9.999921e-01             0.999996            0.999949
# 438251  1.000000e+00             0.999967            1.000000
# 438254  9.999917e-01             1.000000            0.999997
# 438259  9.999981e-01             0.999983            1.000000
#
#         Y_icann_first_17char  Y_private_first_17char  legit  not_dga
# 885             1.955169e-06            3.136467e-01  False    False
# 886             1.955169e-06            3.136467e-01  False    False
# 1156            3.510921e-07            1.278853e-05  False    False
# 1468            3.281455e-09            8.181743e-07  False    False
# 1482            1.411106e-01            7.547356e-06  False    False
# ...                      ...                     ...    ...      ...
# 438238          5.254872e-01            9.946175e-01  False    False
# 438247          9.998803e-01            9.999996e-01  False    False
# 438251          9.999999e-01            9.999998e-01  False    False
# 438254          1.000000e+00            9.999915e-01  False    False
# 438259          9.999993e-01            1.000000e+00  False    False
#
# [51314 rows x 13 columns]

# %%
df_X = pd.read_csv("X.csv")

df_X

df_or['dn'] = df_X['none']

df_or
# Out:
#             id  is_malware  is_dga        Y_none         Y_tld       Y_icann  \
# 0            0           0       0  1.005598e-12  1.556818e-02  2.598478e-04
# 1            1           0       0  6.368934e-09  4.435358e-08  8.998251e-09
# 2            2           0       0  1.234430e-08  1.274059e-04  1.402510e-06
# 3            3           0       0  5.956627e-07  3.501129e-16  8.098094e-08
# 4            4           0       0  6.954845e-10  2.457577e-18  5.336343e-06
# ...        ...         ...     ...           ...           ...           ...
# 438265  438265           1       0  2.705789e-08  1.399286e-02  3.384466e-08
# 438266  438266           1       0  7.792556e-12  1.808250e-08  7.530522e-08
# 438267  438267           1       0  7.774512e-01  1.189371e-01  2.149270e-02
# 438268  438268           1       0  9.999977e-01  9.999644e-01  9.799217e-01
# 438269  438269           1       0  1.922639e-07  1.796599e-15  2.545251e-05
#
#            Y_private  Y_none_first_17char  Y_tld_first_17char  \
# 0       6.312761e-02         4.698381e-08        1.752473e-03
# 1       4.551743e-05         1.545209e-09        3.403100e-06
# 2       8.551755e-03         1.695813e-04        1.991690e-05
# 3       7.502151e-08         4.999577e-09        4.183368e-14
# 4       2.167046e-08         1.455787e-09        9.327148e-15
# ...              ...                  ...                 ...
# 438265  8.182876e-02         9.702229e-01        1.399286e-02
# 438266  1.851927e-06         2.799801e-12        1.808250e-08
# 438267  4.643767e-01         9.999257e-01        1.189371e-01
# 438268  8.686514e-01         9.997970e-01        9.999644e-01
# 438269  1.438012e-06         4.901239e-09        1.796599e-15
#
#         Y_icann_first_17char  Y_private_first_17char  legit  \
# 0               3.849515e-04            2.161021e-06   True
# 1               2.971966e-07            1.740100e-06   True
# 2               1.418202e-08            3.691444e-07   True
# 3               1.145445e-09            1.677584e-05   True
# 4               6.141904e-10            1.078596e-08   True
# ...                      ...                     ...    ...
# 438265          3.384466e-08            8.182876e-02  False
# 438266          7.530522e-08            1.851927e-06  False
# 438267          2.149270e-02            4.643767e-01  False
# 438268          9.799217e-01            8.686514e-01  False
# 438269          2.545251e-05            1.438012e-06  False
#
#                                                        dn
# 0                  0000000000000000000000000000000000.com
# 1                  00000000000000000000.demandware.com.hk
# 2                   00000000000000000000.test-socrata.com
# 3               0-0000-0000-0000-5f64-044217.bbycloud.com
# 4       0-0000-0000-0000-5f64-a104-98-86-241.bbycloud.com
# ...                                                   ...
# 438265                                     zzz.457467.com
# 438266                                   zzz555.tl-ip.com
# 438267                                          zzzsec.tk
# 438268                                  zzzzaaaa.ddns.net
# 438269                                       zz-zz.ath.cx
#
# [438270 rows x 13 columns]

# %%
th = 0.5


for tmp in ['is_malware', 'is_dga', 'not_dga']:

    df = df_or.copy()

    df = df[(df.legit) | (df[tmp])]


    df['good'] = df['legit']
    df['bad'] = df[tmp]


    def cm(row, col):
        if row[col] > 0.5 and row['bad']: return 'tp'
        if row[col] <= 0.5 and row['bad']: return 'fp'
        if row[col] > 0.5 and row['good']: return 'fn'
        if row[col] <= 0.5 and row['good']: return 'tn'
        return 'err'


    results = []
    for col in 'Y_none,Y_tld,Y_icann,Y_private,Y_none_first_17char,Y_tld_first_17char,Y_icann_first_17char,Y_private_first_17char'.split(','):
        s_p = df[col] > th

        n = (df['good']).sum()
        p = (df['bad']).sum()

        # print(df.apply(cm, axis=1, col=col))

        tp = (s_p & (df['bad']))
        tn = ((~s_p) & (df['good']))
        fp = ((s_p) & (df['good']))
        fn = ((~s_p) & (df['bad']))

        df['cm'] = ''

        df['cm'] = df['cm'].where(~tp, 'tp')
        df['cm'] = df['cm'].where(~fn, 'fn')
        df['cm'] = df['cm'].where(~fp, 'fp')
        df['cm'] = df['cm'].where(~tn, 'tn')

#         print(f"{col}")
#         print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
#         print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
#         print(f"TNR:\t{tn.sum()}\t{tn.sum()/n:2.2%}")
#         print(f"FPR:\t{fp.sum()}\t{fp.sum()/n:2.2%}\n")

        results.append([
            col[2:],

            tp.sum(),
            fn.sum(),
            tn.sum(),
            fp.sum(),

            tp.sum() / p,
            fn.sum() / p,
            tn.sum() / n,
            fp.sum() / n,

            tp.sum()/fp.sum()
        ])

        pass

    print(tmp)
    print(pd.DataFrame(results, columns=['nn', 'tp', 'fn', 'tn', 'fp', 'tp%', 'fn%', 'tn%', 'fp%', 'veri/falsi']).to_csv(index=False))
# Out:
# is_malware
# nn,tp,fn,tn,fp,tp%,fn%,tn%,fp%,veri/falsi
# none,69559,168711,198513,1487,0.2919335207957359,0.708066479204264,0.992565,0.007435,46.778076664425015
# tld,55960,182310,199034,966,0.2348596130440257,0.7651403869559743,0.99517,0.00483,57.9296066252588
# icann,57529,180741,199064,936,0.24144457967851596,0.758555420321484,0.99532,0.00468,61.462606837606835
# private,57029,181241,198929,1071,0.2393461199479582,0.7606538800520418,0.994645,0.005355,53.248366013071895
# none_first_17char,71754,166516,193748,6252,0.30114575901288454,0.6988542409871155,0.96874,0.03126,11.476967370441459
# tld_first_17char,48223,190047,198451,1549,0.20238804717337475,0.7976119528266252,0.992255,0.007745,31.131697869593285
# icann_first_17char,48456,189814,198935,1065,0.20336592940781467,0.7966340705921854,0.994675,0.005325,45.498591549295774
# private_first_17char,54587,183683,197595,2405,0.22909724262391404,0.7709027573760859,0.987975,0.012025,22.697297297297297
#
# is_dga
# nn,tp,fn,tn,fp,tp%,fn%,tn%,fp%,veri/falsi
# none,46113,5201,198513,1487,0.8986436450091593,0.10135635499084071,0.992565,0.007435,31.010759919300604
# tld,33939,17375,199034,966,0.6613984487664185,0.3386015512335815,0.99517,0.00483,35.13354037267081
# icann,35186,16128,199064,936,0.6856998090189812,0.3143001909810188,0.99532,0.00468,37.59188034188034
# private,31814,19500,198929,1071,0.6199867482558367,0.3800132517441634,0.994645,0.005355,29.704948646125118
# none_first_17char,40949,10365,193748,6252,0.7980083408036793,0.2019916591963207,0.96874,0.03126,6.549744081893794
# tld_first_17char,26774,24540,198451,1549,0.5217679385742683,0.47823206142573177,0.992255,0.007745,17.284699806326664
# icann_first_17char,26465,24849,198935,1065,0.515746190123553,0.48425380987644695,0.994675,0.005325,24.849765258215964
# private_first_17char,29882,21432,197595,2405,0.5823362045445687,0.41766379545543125,0.987975,0.012025,12.424948024948025
#
# not_dga
# nn,tp,fn,tn,fp,tp%,fn%,tn%,fp%,veri/falsi
# none,23446,163510,198513,1487,0.12540918718842936,0.8745908128115706,0.992565,0.007435,15.767316745124411
# tld,22021,164935,199034,966,0.11778707289415691,0.8822129271058431,0.99517,0.00483,22.79606625258799
# icann,22343,164613,199064,936,0.11950940328205567,0.8804905967179443,0.99532,0.00468,23.870726495726494
# private,25215,161741,198929,1071,0.13487130661759986,0.8651286933824002,0.994645,0.005355,23.54341736694678
# none_first_17char,30805,156151,193748,6252,0.16477139005969318,0.8352286099403068,0.96874,0.03126,4.927223288547665
# tld_first_17char,21449,165507,198451,1549,0.11472752947217527,0.8852724705278248,0.992255,0.007745,13.846998063266623
# icann_first_17char,21991,164965,198935,1065,0.11762660733006697,0.8823733926699331,0.994675,0.005325,20.64882629107981
# private_first_17char,24705,162251,197595,2405,0.13214339202807077,0.8678566079719292,0.987975,0.012025,10.272349272349272

# %%
th = 0.5


df = df_or.copy()


df = df[(df.legit) | ((df.is_malware == 1) & (df.is_dga == 0))]


df['good'] = df['legit']
df['bad'] = df['is_dga']


def cm(row, col):
    if row[col] > 0.5 and row['bad']: return 'tp'
    if row[col] <= 0.5 and row['bad']: return 'fp'
    if row[col] > 0.5 and row['good']: return 'fn'
    if row[col] <= 0.5 and row['good']: return 'tn'
    return 'err'


results = []
for col in 'Y_none,Y_tld,Y_icann,Y_private,Y_none_first_17char,Y_tld_first_17char,Y_icann_first_17char,Y_private_first_17char'.split(','):
    s_p = df[col] > th
    
    n = (df['good']).sum()
    p = (df['bad']).sum()
    
    # print(df.apply(cm, axis=1, col=col))

    tp = (s_p & (df['bad']))
    tn = ((~s_p) & (df['good']))
    fp = ((s_p) & (df['good']))
    fn = ((~s_p) & (df['bad']))
    
    df['cm'] = ''
    
    df['cm'] = df['cm'].where(~tp, 'tp')
    df['cm'] = df['cm'].where(~fn, 'fn')
    df['cm'] = df['cm'].where(~fp, 'fp')
    df['cm'] = df['cm'].where(~tn, 'tn')
    
    print(f"{col}")
    print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
    print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
    print(f"TNR:\t{tn.sum()}\t{tn.sum()/n:2.2%}")
    print(f"FPR:\t{fp.sum()}\t{fp.sum()/n:2.2%}\n")
    
    results.append([
        col[2:],
        tp.sum() / p,
        fp.sum() / n,
        fn.sum() / p,
        tn.sum() / n,
        tp.sum()/fp.sum()
    ])
    # display(df[df['cm'] == 'tn'])
    
    pass

print(pd.DataFrame(results, columns=['nn', 'tp', 'fp', 'fn', 'tn', 'veri/falsi']).to_markdown(index=False))

print(df.shape[0])
# Out:
# Y_none
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	198513	99.26%
# FPR:	1487	0.74%
#
# Y_tld
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	199034	99.52%
# FPR:	966	0.48%
#
# Y_icann
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	199064	99.53%
# FPR:	936	0.47%
#
# Y_private
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	198929	99.46%
# FPR:	1071	0.54%
#
# Y_none_first_17char
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	193748	96.87%
# FPR:	6252	3.13%
#
# Y_tld_first_17char
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	198451	99.23%
# FPR:	1549	0.77%
#
# Y_icann_first_17char
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	198935	99.47%
# FPR:	1065	0.53%
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
# Y_private_first_17char
# TPR:	0	  nan%
# FNR:	0	nan%
# TNR:	197595	98.80%
# FPR:	2405	1.20%
#
# | nn                   |   tp |       fp |   fn |       tn |   veri/falsi |
# |:---------------------|-----:|---------:|-----:|---------:|-------------:|
# | none                 |  nan | 0.007435 |  nan | 0.992565 |            0 |
# | tld                  |  nan | 0.00483  |  nan | 0.99517  |            0 |
# | icann                |  nan | 0.00468  |  nan | 0.99532  |            0 |
# | private              |  nan | 0.005355 |  nan | 0.994645 |            0 |
# | none_first_17char    |  nan | 0.03126  |  nan | 0.96874  |            0 |
# | tld_first_17char     |  nan | 0.007745 |  nan | 0.992255 |            0 |
# | icann_first_17char   |  nan | 0.005325 |  nan | 0.994675 |            0 |
# | private_first_17char |  nan | 0.012025 |  nan | 0.987975 |            0 |
# 386956
# <ipython-input-7-c62b74970be5>:44: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"TPR:\t{tp.sum()}\t{tp.sum()/p:6.2%}")
# <ipython-input-7-c62b74970be5>:45: RuntimeWarning: invalid value encountered in long_scalars
#   print(f"FNR:\t{fn.sum()}\t{fn.sum()/p:02.2%}")
# <ipython-input-7-c62b74970be5>:51: RuntimeWarning: invalid value encountered in long_scalars
#   tp.sum() / p,
# <ipython-input-7-c62b74970be5>:53: RuntimeWarning: invalid value encountered in long_scalars
#   fn.sum() / p,
