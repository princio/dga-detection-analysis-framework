# %%
import pandas as pd

# %%
df = pd.read_csv('tranco_7XQJX.csv', header=None)

df.columns=pd.Index(['rank', 'dn'])
df['whitelist_id']= 28
df = df.reset_index(names='id')

# %%
df[['id', 'whitelist_id', 'dn', 'rank']].to_csv('tranco_full.csv', index=False)
# df[['id', 'whitelist_id', 'dn', 'rank']].to_csv('tranco_1m.csv', index=False)
